# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import fetch_openml

# Load the CIFAR-10 dataset from OpenML
cifar_10 = fetch_openml('CIFAR_10_small', version=1)

# Extract the data and labels
X = cifar_10.data
y = cifar_10.target

# Convert the labels to numeric
y = pd.Categorical(y).codes

# Reshape the data to 32x32 images with 3 color channels (32x32x3)
X = np.array(X).reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)
# The transpose rearranges the dimensions: 
# from (samples, 3 channels, 32 width, 32 height) 
# to (samples, 32 width, 32 height, 3 channels) for proper display

# %%
# Define the class names
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Ensure matplotlib.pyplot is imported
import matplotlib.pyplot as plt

# Display the first 9 unique images from the dataset
plt.figure(figsize=(10, 10))
unique_indices = np.unique(y, return_index=True)[1]
for i in range(10):
    plt.subplot(4, 3, i+1)
    plt.imshow(X[unique_indices[i]])
    plt.title(class_names[y[unique_indices[i]]])
    plt.axis('off')
plt.show()
